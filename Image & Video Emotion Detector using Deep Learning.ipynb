# %% [markdown]
# # Human (Image recognizer/ Video detector) based on emotion

# %%
# import required packages
import cv2
import warnings
warnings.filterwarnings('ignore')
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# Initialize image data generator with rescaling
train_data_gen = ImageDataGenerator(rescale=1./255)
validation_data_gen = ImageDataGenerator(rescale=1./255)

# Preprocess all test images
train_generator = train_data_gen.flow_from_directory(
        'train',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

# Preprocess all train images
validation_generator = validation_data_gen.flow_from_directory(
        'test',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

# create model structure
emotion_model = Sequential()

emotion_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)))
emotion_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation='softmax'))

cv2.ocl.setUseOpenCL(False)

emotion_model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.0001, decay=1e-6), metrics=['accuracy'])

# Train the neural network/model
emotion_model_info = emotion_model.fit_generator(
        train_generator,
        steps_per_epoch=28709 // 64,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=7178 // 64)

# save model structure in jason file
model_json = emotion_model.to_json()
with open("emotion_model.json", "w") as json_file:
    
    json_file.write(model_json)

# save trained model weight in .h5 file
emotion_model.save_weights('emotion_model.h5')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7190 images belonging to 7 classes.
# Epoch 1/50
# 448/448 [==============================] - 265s 590ms/step - loss: 1.8072 - accuracy: 0.2586 - val_loss: 1.7380 - val_accuracy: 0.3323
# Epoch 2/50
# 448/448 [==============================] - 123s 274ms/step - loss: 1.6389 - accuracy: 0.3591 - val_loss: 1.5505 - val_accuracy: 0.4117
# Epoch 3/50
# 448/448 [==============================] - 124s 277ms/step - loss: 1.5258 - accuracy: 0.4140 - val_loss: 1.4587 - val_accuracy: 0.4403
# Epoch 4/50
# 448/448 [==============================] - 125s 279ms/step - loss: 1.4560 - accuracy: 0.4429 - val_loss: 1.4035 - val_accuracy: 0.4729
# Epoch 5/50
# 448/448 [==============================] - 125s 278ms/step - loss: 1.3985 - accuracy: 0.4642 - val_loss: 1.3680 - val_accuracy: 0.4777
# Epoch 6/50
# 448/448 [==============================] - 125s 280ms/step - loss: 1.3491 - accuracy: 0.4890 - val_loss: 1.3119 - val_accuracy: 0.5060
# Epoch 7/50
# 448/448 [==============================] - 126s 282ms/step - loss: 1.3065 - accuracy: 0.5026 - val_loss: 1.2975 - val_accuracy: 0.5116
# Epoch 8/50
# 448/448 [==============================] - 125s 279ms/step - loss: 1.2751 - accuracy: 0.5181 - val_loss: 1.2543 - val_accuracy: 0.5254
# Epoch 9/50
# 448/448 [==============================] - 126s 281ms/step - loss: 1.2372 - accuracy: 0.5334 - val_loss: 1.2351 - val_accuracy: 0.5331
# Epoch 10/50
# 448/448 [==============================] - 125s 278ms/step - loss: 1.2054 - accuracy: 0.5456 - val_loss: 1.2100 - val_accuracy: 0.5444
# Epoch 11/50
# 448/448 [==============================] - 127s 283ms/step - loss: 1.1763 - accuracy: 0.5553 - val_loss: 1.1878 - val_accuracy: 0.5552
# Epoch 12/50
# 448/448 [==============================] - 126s 280ms/step - loss: 1.1471 - accuracy: 0.5673 - val_loss: 1.1839 - val_accuracy: 0.5552
# Epoch 13/50
# 448/448 [==============================] - 125s 278ms/step - loss: 1.1226 - accuracy: 0.5794 - val_loss: 1.1558 - val_accuracy: 0.5658
# Epoch 14/50
# 448/448 [==============================] - 125s 279ms/step - loss: 1.0983 - accuracy: 0.5888 - val_loss: 1.1416 - val_accuracy: 0.5718
# Epoch 15/50
# 448/448 [==============================] - 124s 276ms/step - loss: 1.0733 - accuracy: 0.6014 - val_loss: 1.1344 - val_accuracy: 0.5755
# Epoch 16/50
# 448/448 [==============================] - 127s 283ms/step - loss: 1.0502 - accuracy: 0.6083 - val_loss: 1.1205 - val_accuracy: 0.5811
# Epoch 17/50
# 448/448 [==============================] - 129s 288ms/step - loss: 1.0255 - accuracy: 0.6183 - val_loss: 1.1165 - val_accuracy: 0.5770
# Epoch 18/50
# 448/448 [==============================] - 128s 285ms/step - loss: 1.0038 - accuracy: 0.6291 - val_loss: 1.1158 - val_accuracy: 0.5840
# Epoch 19/50
# 448/448 [==============================] - 134s 298ms/step - loss: 0.9793 - accuracy: 0.6373 - val_loss: 1.0979 - val_accuracy: 0.5910
# Epoch 20/50
# 448/448 [==============================] - 128s 287ms/step - loss: 0.9589 - accuracy: 0.6449 - val_loss: 1.0919 - val_accuracy: 0.5946
# Epoch 21/50
# 448/448 [==============================] - 133s 296ms/step - loss: 0.9372 - accuracy: 0.6535 - val_loss: 1.0991 - val_accuracy: 0.5933
# Epoch 22/50
# 448/448 [==============================] - 128s 287ms/step - loss: 0.9125 - accuracy: 0.6632 - val_loss: 1.0833 - val_accuracy: 0.5995
# Epoch 23/50
# 448/448 [==============================] - 131s 293ms/step - loss: 0.8916 - accuracy: 0.6688 - val_loss: 1.0825 - val_accuracy: 0.6039
# Epoch 24/50
# 448/448 [==============================] - 127s 284ms/step - loss: 0.8724 - accuracy: 0.6803 - val_loss: 1.0738 - val_accuracy: 0.6027
# Epoch 25/50
# 448/448 [==============================] - 131s 292ms/step - loss: 0.8465 - accuracy: 0.6914 - val_loss: 1.0746 - val_accuracy: 0.6028
# Epoch 26/50
# 448/448 [==============================] - 139s 311ms/step - loss: 0.8322 - accuracy: 0.6957 - val_loss: 1.0832 - val_accuracy: 0.6074
# Epoch 27/50
# 448/448 [==============================] - 144s 321ms/step - loss: 0.8056 - accuracy: 0.7047 - val_loss: 1.0721 - val_accuracy: 0.6074
# Epoch 28/50
# 448/448 [==============================] - 147s 328ms/step - loss: 0.7869 - accuracy: 0.7114 - val_loss: 1.0766 - val_accuracy: 0.6099
# Epoch 29/50
# 448/448 [==============================] - 140s 312ms/step - loss: 0.7630 - accuracy: 0.7213 - val_loss: 1.0855 - val_accuracy: 0.6091
# Epoch 30/50
# 448/448 [==============================] - 141s 314ms/step - loss: 0.7401 - accuracy: 0.7285 - val_loss: 1.0782 - val_accuracy: 0.6119
# Epoch 31/50
# 448/448 [==============================] - 131s 291ms/step - loss: 0.7171 - accuracy: 0.7395 - val_loss: 1.0830 - val_accuracy: 0.6151
# Epoch 32/50
# 448/448 [==============================] - 128s 285ms/step - loss: 0.6966 - accuracy: 0.7485 - val_loss: 1.0866 - val_accuracy: 0.6187
# Epoch 33/50
# 448/448 [==============================] - 133s 296ms/step - loss: 0.6790 - accuracy: 0.7551 - val_loss: 1.0834 - val_accuracy: 0.6152
# Epoch 34/50
# 448/448 [==============================] - 137s 306ms/step - loss: 0.6546 - accuracy: 0.7626 - val_loss: 1.0994 - val_accuracy: 0.6152
# Epoch 35/50
# 448/448 [==============================] - 132s 294ms/step - loss: 0.6330 - accuracy: 0.7713 - val_loss: 1.1114 - val_accuracy: 0.6190
# Epoch 36/50
# 448/448 [==============================] - 128s 285ms/step - loss: 0.6129 - accuracy: 0.7766 - val_loss: 1.1173 - val_accuracy: 0.6157
# Epoch 37/50
# 448/448 [==============================] - 127s 284ms/step - loss: 0.5972 - accuracy: 0.7842 - val_loss: 1.1031 - val_accuracy: 0.6186
# Epoch 38/50
# 448/448 [==============================] - 126s 281ms/step - loss: 0.5755 - accuracy: 0.7931 - val_loss: 1.1136 - val_accuracy: 0.6170
# Epoch 39/50
# 448/448 [==============================] - 127s 283ms/step - loss: 0.5630 - accuracy: 0.7944 - val_loss: 1.1238 - val_accuracy: 0.6243
# Epoch 40/50
# 448/448 [==============================] - 128s 285ms/step - loss: 0.5436 - accuracy: 0.8037 - val_loss: 1.1334 - val_accuracy: 0.6228
# Epoch 41/50
# 448/448 [==============================] - 127s 284ms/step - loss: 0.5241 - accuracy: 0.8102 - val_loss: 1.1370 - val_accuracy: 0.6215
# Epoch 42/50
# 448/448 [==============================] - 134s 300ms/step - loss: 0.5091 - accuracy: 0.8158 - val_loss: 1.1355 - val_accuracy: 0.6194
# Epoch 43/50
# 448/448 [==============================] - 127s 284ms/step - loss: 0.4915 - accuracy: 0.8223 - val_loss: 1.1470 - val_accuracy: 0.6214
# Epoch 44/50
# 448/448 [==============================] - 126s 280ms/step - loss: 0.4809 - accuracy: 0.8266 - val_loss: 1.1461 - val_accuracy: 0.6217
# Epoch 45/50
# 448/448 [==============================] - 128s 285ms/step - loss: 0.4644 - accuracy: 0.8320 - val_loss: 1.1635 - val_accuracy: 0.6201
# Epoch 46/50
# 448/448 [==============================] - 127s 282ms/step - loss: 0.4500 - accuracy: 0.8390 - val_loss: 1.1783 - val_accuracy: 0.6257
# Epoch 47/50
# 448/448 [==============================] - 125s 279ms/step - loss: 0.4348 - accuracy: 0.8416 - val_loss: 1.1791 - val_accuracy: 0.6243
# Epoch 48/50
# 448/448 [==============================] - 125s 279ms/step - loss: 0.4212 - accuracy: 0.8472 - val_loss: 1.1950 - val_accuracy: 0.6201
# Epoch 49/50
# 448/448 [==============================] - 126s 281ms/step - loss: 0.4088 - accuracy: 0.8538 - val_loss: 1.2053 - val_accuracy: 0.6223
# Epoch 50/50
# 448/448 [==============================] - 125s 278ms/step - loss: 0.4077 - accuracy: 0.8520 - val_loss: 1.1877 - val_accuracy: 0.6210
